# %%
import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.backends.backend_pdf as pdf
import matplotlib.patches as pch

import eleanor_constants as EL

matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %matplotlib inline
savename = "./figures/4.pdf"

# %%
df = pd.read_csv("./data/trajectories/summary/cleaned_animal_analyses_stimuli_groups.csv")
print(max(df["c_speed_diff"]), min(df["c_speed_diff"]))
print(max(df["median_conc_diff"]), min(df["median_conc_diff"]))

w = df[df['stimulus'] == "Neutral"]
f = df[df['stimulus'] == "Appetitive"]
q = df[df['stimulus'] == "Aversive"]
# Out:
# 1.3726565374155162 -1.2661725109194562
# 65.0615 -66.09066666666668

# %%
fig = plt.figure(figsize=(7.125, 9))
grid = matplotlib.gridspec.GridSpec(5, 5)

ax1 = fig.add_subplot(grid[1:4, 0:4], facecolor="None")
ax2 = fig.add_subplot(grid[0, 0:4], facecolor="None")
ax3 = fig.add_subplot(grid[1:4, 4], facecolor="None")
ax4 = fig.add_subplot(grid[0, 4], facecolor="None")

ax1.set_xlim(-70, 70)
ax1.set_xticks(np.arange(-70, 71, 10))
ax1.set_xticks(np.arange(-70, 71, 5), minor=True)
ax1.set_ylim(-1.4, 1.4)
ax1.set_yticks(np.arange(-1.4, 1.41, 0.2))
ax1.set_yticks(np.arange(-1.4, 1.4, 0.1), minor=True)

ax2.set_xlim(-70, 70)
ax2.set_xticks(np.arange(-70, 71, 10))
ax2.set_xticks(np.arange(-70, 71, 5), minor=True)

ax3.set_ylim(-1.4, 1.4)
ax3.set_yticks(np.arange(-1.4, 1.41, 0.2))
ax3.set_yticks(np.arange(-1.4, 1.4, 0.2), minor=True)

ax1.spines['left'].set_position('center')
ax1.spines['bottom'].set_position('center')
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)

ax1.scatter(w.median_conc_diff, w.c_speed_diff, color=EL.c_water, marker="^", s=EL.s, alpha=1, label="Neutral", clip_on=False)
# ax1.scatter(w.median_conc_diff, w.c_speed_diff, color=EL.c_water, lw=0, s=EL.s*50, alpha=0.05, clip_on=False, label=None)

ax1.scatter(f.median_conc_diff, f.c_speed_diff, color=EL.c_food, marker="o", s=EL.s, alpha=1, label="Attractive", clip_on=False)
# ax1.scatter(f.median_conc_diff, f.c_speed_diff, color=EL.c_food, lw=0, s=EL.s*50, alpha=0.05, clip_on=False, label=None)

ax1.scatter(q.median_conc_diff, q.c_speed_diff, color=EL.c_quinine, marker="x", s=EL.s+5, alpha=1, label="Aversive", clip_on=False)
# ax1.scatter(q.median_conc_diff, q.c_speed_diff, color=EL.c_quinine, lw=0, s=EL.s*50, alpha=0.05, clip_on=False, label=None)

bn = 60
ax2.set_xlim(-70, 70)
bins=np.linspace(-70, 70, bn)
bit = 120*0.0075
ax2.hist(w.median_conc_diff, bins=bins, color=EL.c_water, alpha=0.5, label="Neutral", normed=True)
ax2.hist(f.median_conc_diff, bins=bins, color=EL.c_food, alpha=0.5, label="Attractive", normed=True)
ax2.hist(q.median_conc_diff, bins=bins, color=EL.c_quinine, alpha=0.5, label="Aversive", normed=True)
ax2.axvline(x=np.mean(f.median_conc_diff), ymin=0, ymax=1, color=EL.c_food, alpha=1, label=None)
ax2.axvline(x=np.mean(w.median_conc_diff), ymin=0, ymax=1, color=EL.c_water, alpha=1, label=None)
ax2.axvline(x=np.mean(q.median_conc_diff), ymin=0, ymax=1, color=EL.c_quinine, alpha=1, label=None)
ax2.axvline(x=0, ymin=0, ymax=1, color='k', ls="dotted", alpha=0.5, label=None)
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.set_yticks([])

ax3.set_ylim(-1.4, 1.4)
bins=np.linspace(-1.4, 1.4, bn)
bit = 1.4*2*0.0075
ax3.hist(w.c_speed_diff, bins=bins, color=EL.c_water, alpha=0.5, label="Neutral", normed=True, orientation="horizontal")
ax3.hist(f.c_speed_diff, bins=bins, color=EL.c_food, alpha=0.5, label="Attractive", normed=True, orientation="horizontal")
ax3.hist(q.c_speed_diff, bins=bins, color=EL.c_quinine, alpha=0.5, label="Aversive", normed=True, orientation="horizontal")
ax3.axhline(y=np.mean(f.c_speed_diff), xmin=0, xmax=1, color=EL.c_food, alpha=1, label=None)
ax3.axhline(y=np.mean(w.c_speed_diff), xmin=0, xmax=1, color=EL.c_water, alpha=1, label=None)
ax3.axhline(y=np.mean(q.c_speed_diff), xmin=0, xmax=1, color=EL.c_quinine, alpha=1, label=None)
ax3.axhline(y=0, xmin=0, xmax=1, color='k', ls="dotted", alpha=0.5, label=None)
ax3.spines['right'].set_visible(False)
ax3.spines['top'].set_visible(False)
ax3.spines['bottom'].set_visible(False)
ax3.set_xticks([])

ax1.set_yticks([])
ax1.set_xticks([])

handles, lab = ax1.get_legend_handles_labels()
lab, handles = zip(*sorted(zip(lab, handles), key=lambda t: t[0]))
handles1, lab1 = ax2.get_legend_handles_labels()
lab1, handles1 = zip(*sorted(zip(lab1, handles1), key=lambda t: t[0]))
handles = handles + handles1
lab = lab + lab1
ax4.legend(handles, lab, frameon=False, loc='upper left', handletextpad=0.5, 
          bbox_to_anchor=(-0.3, 0, 1, 0.95), ncol=1, columnspacing=0.55, markerscale=2)
ax4.axis("off")

diff2 = (ax1.get_ylim()[1]-ax1.get_ylim()[0])*0.019
ax1.text(ax1.get_xlim()[0], diff2, r"${\Delta P}$", va="center", ha="left")

diff2 = (ax2.get_ylim()[1]-ax2.get_ylim()[0])*0.071
ax2.text(ax2.get_xlim()[0], diff2, r"${\Delta P}$", va="center", ha="left")

diff1 = (ax1.get_xlim()[1]-ax1.get_xlim()[0])*0.015
ax1.text(diff1, ax1.get_ylim()[0], r"${\Delta CS}$", ha="left", va="bottom", rotation=90)

diff1 = (ax3.get_xlim()[1]-ax3.get_xlim()[0])*0.11
ax3.text(diff1, ax3.get_ylim()[0], r"${\Delta CS}$", ha="left", va="bottom", rotation=90)

# SET BOUNDARIES AND SAVE FIGURE -----------------------------------------------
plt.tight_layout()
# fig.subplots_adjust(hspace=0.3, wspace=0.55)
pp = pdf.PdfPages(savename, keep_empty=False)
pp.savefig(fig)
pp.close()
plt.show()
# Out:
# C:\Users\Eleanor\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
